# %% [markdown]
# **3/28/25**
#
# The purpose of this notebook is to graph results from colonization experiment of EpiVaginal tissue by *G. vaginalis* 315-A and *H. timonensis* 5C-B1 with and without mucin.

# %%
from elliot_utils import *

# %%
analysisPath = Path.cwd().joinpath('analysis_files/epivaginal_mucin/')
figPath = Path.cwd().joinpath('figures/epivaginal_mucin/')

# %%
# Make graphs of G. vaginalis growth
gardnerellaData = pd.read_csv(analysisPath.joinpath('qpcr_gardnerella.csv'))

# %%
plot = sns.catplot(data=sliceDFBy(gardnerellaData, ['Sample'], [['Gv Muc']]), x='Time', y='Fold-Growth', hue='Replicate Code', capsize=.2, errorbar='se', kind='point', aspect=1.1)
plot.set(title='G. vaginalis + Mucin', xlabel='Time (hours)')

# %%
plot = sns.catplot(data=sliceDFBy(gardnerellaData, ['Sample'], [['Gv']]), x='Time', y='Fold-Growth', hue='Replicate Code', capsize=.2, errorbar='se', kind='point', aspect=1.1)
plot.set(title='G. vaginalis Monoculture', xlabel='Time (hours)')

# %%
plot = sns.catplot(data=sliceDFBy(gardnerellaData, ['Sample'], [['Gv Ht Muc']]), x='Time', y='Fold-Growth', hue='Replicate Code', capsize=.2, errorbar='se', kind='point', aspect=1.1)
plot.set(title='G. vaginalis + H. timonensis + mucin', xlabel='Time (hours)')

# %%
plot = sns.catplot(data=sliceDFBy(gardnerellaData, ['Sample'], [['Gv Ht']]), x='Time', y='Fold-Growth', hue='Replicate Code', capsize=.2, errorbar='se', kind='point', aspect=1.1)
plot.set(title='G. vaginalis + H. timonensis', xlabel='Time (hours)')

# %%
plot = sns.catplot(data=sliceDFBy(gardnerellaData, ['Sample'], [['Gv Ht Muc Zan']]), x='Time', y='Fold-Growth', hue='Replicate Code', capsize=.2, errorbar='se', kind='point', aspect=1.1)
plot.set(title='G. vaginalis + H. timonensis + Mucin + Zanamivir', xlabel='Time (hours)')

# %%
plot = sns.catplot(data=sliceDFBy(gardnerellaData, ['Sample'], [['Gv Muc', 'Gv']]), x='Time', y='16S/μL', hue='Sample', capsize=.2, errorbar='se', kind='point', aspect=1.1, palette=['palegreen', 'lightgray'])
plot.set(yscale='log', ylim=(1e4, 1e7), title='Mucin effect', xlabel='Time (hours)', ylabel='Gardnerella 16S/μL')

# %%
plot = sns.catplot(data=sliceDFBy(gardnerellaData, ['Sample'], [['Gv', 'Gv Ht']]), x='Time', y='16S/μL', hue='Sample', capsize=.2, errorbar='se', kind='point', aspect=1.1, palette=['lightgray', 'gray'])
plot.set(yscale='log', ylim=(1e4, 1e7), title='Ht Effect', xlabel='Time (hours)', ylabel='Gardnerella 16S/μL')

# %%
plot = sns.catplot(data=sliceDFBy(gardnerellaData, ['Sample'], [['Gv Muc', 'Gv Ht Muc']]), x='Time', y='Fold-Growth', hue='Sample', capsize=.2, errorbar='se', kind='point', aspect=1.1, palette=['palegreen', 'green'])
plot.set(title='H. timonensis in mucin effect', xlabel='Time (hours)')

# %%
plot = sns.catplot(data=sliceDFBy(gardnerellaData, ['Sample'], [['Gv Muc', 'Gv Ht Muc']]), x='Time', y='16S/μL', hue='Sample', capsize=.2, errorbar='se', kind='point', aspect=1.1, palette=['palegreen', 'green'])
plot.set(yscale='log', ylim=(1e4, 1e7), title='H. timonensis in mucin effect', xlabel='Time (hours)')

# %%
plot = sns.catplot(data=sliceDFBy(gardnerellaData, ['Sample'], [['Gv Ht Muc', 'Gv Ht']]), x='Time', y='Fold-Growth', hue='Sample', capsize=.2, errorbar='se', kind='point', aspect=1.1, palette=['green', 'gray'])
plot.set(title='Coculture Mucin Effect', xlabel='Time (hours)')

# %%
plot = sns.catplot(data=sliceDFBy(gardnerellaData, ['Sample'], [['Gv Ht Muc', 'Gv Ht']]), x='Time', y='16S/μL', hue='Sample', capsize=.2, errorbar='se', kind='point', aspect=1.1, palette=['green', 'gray'])
plot.set(yscale='log', ylabel='Gardnerella 16S/μL', ylim=(1e4, 1e7), title='Coculture Mucin Effect', xlabel='Time (hours)')

# %%
plot = sns.catplot(data=sliceDFBy(gardnerellaData, ['Sample'], [['Gv Ht Muc', 'Gv Ht Muc Zan']]), x='Time', y='16S/μL', hue='Sample', capsize=.2, errorbar='se', kind='point', aspect=1.1, palette=['green', 'orange'])
plot.set(yscale='log', ylim=(1e4, 1e7), ylabel='Gardnerella 16S/μL', title='Zanamivir Effect', xlabel='Time (hours)')

# %%
plot = sns.catplot(data=sliceDFBy(gardnerellaData, ['Sample'], [['Gv Muc', 'Gv', 'Gv Ht Muc', 'Gv Ht']]), x='Time', y='Fold-Growth', hue='Sample', capsize=.2, errorbar='se', kind='point', aspect=1.1, palette=['palegreen', 'lightgray', 'green', 'gray'])
plot.set(title='Combined Results', xlabel='Time (hours)')

# %%
plot = sns.catplot(data=sliceDFBy(gardnerellaData, ['Sample'], [['Gv Muc', 'Gv', 'Gv Ht Muc', 'Gv Ht']]), x='Time', y='16S/μL', hue='Sample', capsize=.2, errorbar='se', kind='point', aspect=1.1, palette=['palegreen', 'lightgray', 'green', 'gray'])
plot.set(yscale='log', ylim=(1e4, 1e7), title='Combined Results', xlabel='Time (hours)')

# %%
# Next let's take a look at the H. timonensis data from the combined datafile
combinedData = pd.read_csv(analysisPath.joinpath('qpcr_combined.csv'))

# %%
plot = sns.catplot(data=sliceDFBy(combinedData, ['Sample', 'Species'], [['Gv Ht Muc'], ['H. timonensis']]), x='Time', y='Fold-Growth', hue='Replicate Code', capsize=.2, errorbar='se', kind='point', aspect=1.1)
plot.set(title='Gv Ht Muc', ylabel='$\it{H. timonensis}$ fold-growth', xlabel='Time (hours)')

# %%
plot = sns.catplot(data=sliceDFBy(combinedData, ['Sample', 'Species'], [['Gv Ht'], ['H. timonensis']]), x='Time', y='Fold-Growth', hue='Replicate Code', capsize=.2, errorbar='se', kind='point', aspect=1.1)
plot.set(title='Gv Ht', ylabel='$\it{H. timonensis}$ fold-growth', xlabel='Time (hours)')

# %%
plot = sns.catplot(data=sliceDFBy(combinedData, ['Sample', 'Species'], [['Gv Ht Muc Zan'], ['H. timonensis']]), x='Time', y='Fold-Growth', hue='Replicate Code', capsize=.2, errorbar='se', kind='point', aspect=1.1)
plot.set(title='Gv Ht Muc Zan', ylabel='$\it{H. timonensis}$ fold-growth', xlabel='Time (hours)')

# %%
plot = sns.catplot(data=sliceDFBy(combinedData, ['Sample', 'Species'], [['Gv Ht Muc', 'Gv Ht', 'Gv Ht Muc Zan'], ['H. timonensis']]), x='Time', y='Fold-Growth', hue='Sample', capsize=.2, errorbar='se', kind='point', aspect=1.1)
plot.set(title='H. timonensis Combined', ylabel='$\it{H. timonensis}$ fold-growth', xlabel='Time (hours)')

# %%
plot = sns.catplot(data=sliceDFBy(combinedData, ['Sample', 'Species'], [['Gv Ht Muc'], ['G. vaginalis', 'H. timonensis']]), x='Time', y='16S/μL', hue='Species', capsize=.2, errorbar='se', kind='point', aspect=1.1, palette=['#FF007F', '#5047FF'])
plot.set(yscale='log', ylim=(1e3, 1e7), title='+Mucin Coculture', ylabel='16S rRNA gene copies per μL', xlabel='Time (hours)')

# %%
plot = sns.catplot(data=sliceDFBy(combinedData, ['Species'], [['H. timonensis']]), x='Time', y='Fold-Growth', hue='Sample', capsize=.2, errorbar='se', kind='point', aspect=1.1)
plot.set(title='H. timonensis Combined Results', ylabel='16S rRNA gene copies per μL', xlabel='Time (hours)')

# %%
plot = sns.catplot(data=sliceDFBy(combinedData, ['Species'], [['H. timonensis']]), x='Time', y='16S/μL', hue='Sample', capsize=.2, errorbar='se', kind='point', aspect=1.1)
plot.set(yscale='log', ylim=(1e3, 1e6), title='H. timonensis Combined Results', ylabel='16S rRNA gene copies per μL', xlabel='Time (hours)')

# %%
plot = sns.catplot(data=sliceDFBy(combinedData, ['Sample'], [['Gv Ht']]), x='Time', y='16S/μL', hue='Species', capsize=.2, errorbar='se', kind='point', aspect=1.1, palette=['#FF007F', '#5047FF'])
plot.set(yscale='log', ylim=(1e3, 1e7), title='Control Coculture', ylabel='16S rRNA gene copies per μL', xlabel='Time (hours)')

# %%
plot = sns.catplot(data=sliceDFBy(combinedData, ['Sample'], [['Gv Ht Muc Zan']]), x='Time', y='16S/μL', hue='Species', capsize=.2, errorbar='se', kind='point', aspect=1.1, palette=['#FF007F', '#5047FF'])
plot.set(yscale='log', ylim=(1e4, 1e7), title='+Mucin +Zanamivir Coculture', ylabel='16S rRNA gene copies per μL', xlabel='Time (hours)')

# %%
# Take a look at the human data
combinedData = pd.read_csv(analysisPath.joinpath('qpcr_combined.csv'))

# %%
plot = sns.catplot(data=sliceDFBy(combinedData, ['Sample', 'Species'], [['Gv Muc'], ['Human']]), x='Time', y='16S/μL', hue='Replicate Code', capsize=.2, errorbar='se', kind='point', aspect=1.1)
plot.set(title='Gv Muc', ylabel='Human DNA (pg/μL)', xlabel='Time (hours)')

# %%
plot = sns.catplot(data=sliceDFBy(combinedData, ['Sample', 'Species'], [['Gv'], ['Human']]), x='Time', y='16S/μL', hue='Replicate Code', capsize=.2, errorbar='se', kind='point', aspect=1.1)
plot.set(title='Gv', ylabel='Human DNA (pg/μL)', xlabel='Time (hours)')

# %%
plot = sns.catplot(data=sliceDFBy(combinedData, ['Sample', 'Species'], [['Gv Ht Muc'], ['Human']]), x='Time', y='16S/μL', hue='Replicate Code', capsize=.2, errorbar='se', kind='point', aspect=1.1)
plot.set(title='Gv Ht Muc', ylabel='Human DNA (pg/μL)', xlabel='Time (hours)')

# %%
plot = sns.catplot(data=sliceDFBy(combinedData, ['Sample', 'Species'], [['Gv Ht'], ['Human']]), x='Time', y='16S/μL', hue='Replicate Code', capsize=.2, errorbar='se', kind='point', aspect=1.1)
plot.set(yscale='log', title='Gv Ht', ylabel='Human DNA (pg/μL)', xlabel='Time (hours)')

# %%
plot = sns.catplot(data=sliceDFBy(combinedData, ['Sample', 'Species'], [['Gv Ht Muc Zan'], ['Human']]), x='Time', y='16S/μL', hue='Replicate Code', capsize=.2, errorbar='se', kind='point', aspect=1.1)
plot.set(title='Gv Ht Muc Zan', ylabel='Human DNA (pg/μL)', xlabel='Time (hours)')

# %%
plot = sns.catplot(data=sliceDFBy(combinedData, ['Sample', 'Species'], [['Gv Muc', 'Gv', 'Gv Ht Muc', 'Gv Ht', 'Gv Ht Muc Zan'], ['Human']]), x='Time', y='16S/μL', hue='Sample', capsize=.2, errorbar='se', kind='point', aspect=1.1)
plot.set(title='Human Combined', ylabel='Human DNA (pg/μL)', xlabel='Time (hours)')

# %%
plot = sns.catplot(data=sliceDFBy(combinedData, ['Sample', 'Species'], [['Gv', 'Gv Ht'], ['Human']]), x='Time', y='16S/μL', hue='Sample', capsize=.2, errorbar='se', kind='point', aspect=1.1, palette=['lightgray', 'gray'])
plot.set(title='Human DNA', ylim=(0, 500), ylabel='Human DNA (pg/μL)', xlabel='Time (hours)')

# %%
plot = sns.catplot(data=sliceDFBy(combinedData, ['Sample', 'Species'], [['Gv Ht Muc', 'Gv Ht Muc Zan'], ['H. timonensis']]), x='Time', y='16S/μL', hue='Sample', capsize=.2, errorbar='se', kind='point', aspect=1.1, palette=['green', 'orange'])
plot.set(yscale='log', ylim=(1e4, 3e5), title='Zanamivir Effect', ylabel='H. timonensis 16S/μL', xlabel='Time (hours)')

# %%
plot = sns.catplot(data=sliceDFBy(combinedData, ['Sample'], [['Gv']]), x='Time', y='16S/μL', hue='Species', capsize=.2, errorbar='se', kind='point', aspect=1.1, palette=['#FF007F', '#000000'])
plot.set(yscale='log', ylim=(1e1, 1e7), title='Gv Monoculture', ylabel='16S rRNA gene copies per μL', xlabel='Time (hours)')

# %%
plot = sns.catplot(data=sliceDFBy(combinedData, ['Sample'], [['Gv Muc']]), x='Time', y='16S/μL', hue='Species', capsize=.2, errorbar='se', kind='point', aspect=1.1, palette=['#FF007F', '#000000'])
plot.set(yscale='log', ylim=(1e0, 1e7), title='Gv +Mucin', ylabel='16S rRNA gene copies per μL', xlabel='Time (hours)')

# %%
plot = sns.catplot(data=sliceDFBy(combinedData, ['Sample'], [['Gv Ht Muc']]), x='Time', y='16S/μL', hue='Species', capsize=.2, errorbar='se', kind='point', aspect=1.1, palette=['#FF007F', '#5047FF', '#000000'])
plot.set(yscale='log', ylim=(1e0, 1e7), title='Gv Ht +Mucin', ylabel='16S rRNA gene copies per μL', xlabel='Time (hours)')

# %%
plot = sns.catplot(data=sliceDFBy(combinedData, ['Sample'], [['Gv Ht']]), x='Time', y='16S/μL', hue='Species', capsize=.2, errorbar='se', kind='point', aspect=1.1, palette=['#FF007F', '#5047FF', '#000000'])
plot.set(yscale='log', ylim=(1e0, 1e7), title='Gv Ht', ylabel='16S rRNA gene copies per μL', xlabel='Time (hours)')

# %%
# Graphs for publication
plot = sns.catplot(data=sliceDFBy(combinedData, ['Culture', 'Species'], [['Gv Vehicle', 'Gv Mucin', 'Gv+Ht Vehicle', 'Gv+Ht Mucin'], ['G. vaginalis']]), x='Time', y='Fold-Growth', hue='Culture', capsize=.2, errorbar='se', kind='point', aspect=1.1, palette=['lightgray', 'palegreen', 'gray', 'green'], markers=['o', 'o', 's', 's'])
plot.set(yscale='log', ylabel='$\it{G. vaginalis}$ Fold-Growth', xlabel='Time (hours)')
plot.savefig(figPath.joinpath('gardnerella_epivaginal_foldgrowth.png'), dpi=300, bbox_inches='tight')

# %%
plot = sns.catplot(data=sliceDFBy(combinedData, ['Culture', 'Species'], [['Gv+Ht Vehicle', 'Gv+Ht Mucin'], ['H. timonensis']]), x='Time', y='Fold-Growth', hue='Culture', capsize=.2, errorbar='se', kind='point', aspect=1.1, palette=['gray', 'green'], markers=['s', 's'])
plot.set(yscale='log', ylabel='$\it{H. timonensis}$ Fold-Growth', xlabel='Time (hours)')
plot.savefig(figPath.joinpath('hoylesella_epivaginal_foldgrowth.png'), dpi=300, bbox_inches='tight')

# %%
plot = sns.catplot(data=sliceDFBy(combinedData, ['Culture', 'Species', 'Time'], [['Gv Vehicle', 'Gv Mucin', 'Gv+Ht Vehicle', 'Gv+Ht Mucin'], ['Human'], [24, 48, 72]]), x='Time', y='16S/μL', hue='Culture', capsize=.14, errorbar='se', kind='point', aspect=1.1, palette=['lightgray', 'palegreen', 'gray', 'green'], markers=['o', 'o', 's', 's'])
plot.set(yscale='log', ylim=(1e0, 1e3), ylabel='Human DNA (pg/μL)', xlabel='Time (hours)')
plot.savefig(figPath.joinpath('human_epivaginal_dna.png'), dpi=300, bbox_inches='tight')

# %%
plot = sns.catplot(data=sliceDFBy(combinedData, ['Culture', 'Species'], [['Gv+Ht Mucin', 'Gv+Ht Mucin+Zanamivir'], ['G. vaginalis']]), x='Time', y='Fold-Growth', hue='Culture', capsize=.2, errorbar='se', kind='point', aspect=1.1, palette=['green', 'orange'], markers=['o', 'o', 's', 's'])
plot.set(yscale='log', ylabel='$\it{G. vaginalis}$ Fold-Growth', xlabel='Time (hours)')
plot.savefig(figPath.joinpath('gardnerella_epivaginal_zanamivir.png'), dpi=300, bbox_inches='tight')

# %%
plot = sns.catplot(data=sliceDFBy(combinedData, ['Culture', 'Species'], [['Gv+Ht Mucin', 'Gv+Ht Mucin+Zanamivir'], ['H. timonensis']]), x='Time', y='Fold-Growth', hue='Culture', capsize=.2, errorbar='se', kind='point', aspect=1.1, palette=['green', 'orange'], markers=['o', 'o', 's', 's'])
plot.set(yscale='log', ylabel='$\it{H. timonensis}$ Fold-Growth', xlabel='Time (hours)')
plot.savefig(figPath.joinpath('hoylesella_epivaginal_zanamivir.png'), dpi=300, bbox_inches='tight')

# %%
dataToPlot = sliceDFBy(combinedData, ['Culture', 'Species', 'Time', 'Sample'], [['Gv Mucin', 'Gv Vehicle', 'NGv Mucin', 'NGv', 'Gv+Ht Mucin', 'NGv+Ht Mucin', 'NGv+Ht', 'Gv+Ht Vehicle'], ['G. vaginalis', 'H. timonensis'], [72], ['Control']])
plot = sns.catplot(data=dataToPlot, x='Treatment', y='Fold-Growth', hue='Species', kind='bar', aspect=1.1, palette=['gray', 'darkgray'])
plot.set_xticklabels(rotation=30, ha='right')
plot.set(yscale='log', ylim=(1e-2, 2e0), ylabel='Fold-Growth', xlabel='')
plt.axhline(1e0, ls='--', color='black')
plot.savefig(figPath.joinpath('negative_controls.png'), dpi=300, bbox_inches='tight')

# %%
plot = sns.catplot(data=sliceDFBy(combinedData, ['Culture', 'Species'], [['Gv+Ht Mucin', 'Gv+Ht Mucin+Zanamivir'], ['Human']]), x='Time', y='16S/μL', hue='Culture', capsize=.2, errorbar='se', kind='point', aspect=1.1, palette=['green', 'orange'], markers=['o', 'o', 's', 's'])
plot.set(ylim=(0, 400), xlabel='Time (hours)', ylabel='Human DNA (pg/μL)')
plot.savefig(figPath.joinpath('human_epivaginal_zanamivir.png'), dpi=300, bbox_inches='tight')
